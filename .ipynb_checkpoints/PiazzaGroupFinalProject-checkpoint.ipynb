# %%
import pandas as pd
import numpy as np
import scipy.io as sc
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split

# %%
#import social factors
soc_df = pd.read_csv("datasets/after/mergedSOC.csv", index_col=0)
print(soc_df.shape)
soc_df.head()
# Out:
# (51, 336)
#           00L13  01L13  02L13  03L13  04L13  05L13  06L13  07L13  08L13  \
# county
# Angelina    8.8    6.8   48.6   19.6   16.3    7.4   14.5   29.6   26.6
# Bastrop     3.1    8.3   50.9   20.1   17.6   10.3   10.1   31.0   24.5
# Bell        5.6    5.5   41.7   16.9   30.3    4.4    4.1   30.2   28.3
# Bexar       6.0    4.9   40.8   20.2   28.0    7.9    8.4   26.5   23.1
# Bowie       1.8    5.8   49.0   23.7   19.6    2.4    9.7   38.2   25.9
#
#           09L13  ...  38L19  39L19  40L19  41L19  42L19  43L19  44L19  45L19  \
# county           ...
# Angelina    6.1  ...   28.7   55.5    1.3    3.6   10.9   23.0   51.3    2.9
# Bastrop     6.6  ...   36.0   47.3    1.1    2.2   13.5   27.4   43.3    1.0
# Bell       10.2  ...   33.7   51.8    2.4    2.3    9.8   31.6   45.4    2.1
# Bexar       7.4  ...   42.5   42.5    2.7    2.2   10.1   35.1   39.9    3.7
# Bowie       5.1  ...   32.7   46.2    2.2    3.8   15.2   25.3   48.8    2.5
#
#           46L19  47L19
# county
# Angelina    6.8   16.0
# Bastrop    11.3   17.0
# Bell        7.7   13.2
# Bexar       7.7   13.6
# Bowie      10.5   12.9
#
# [5 rows x 336 columns]

# %%
#import hospital discharge data
hd_df = pd.read_csv("datasets/after/mergedIP.csv", index_col=0)
print(hd_df.shape)
hd_df.head()
# Out:
# (51, 28)
#               1q13      2q13      3q13      4q13      1q14      2q14  \
# county
# Angelina  3.565987  3.940571  3.754997  4.523638  3.707047  3.832749
# Bastrop   0.130571  0.113250  0.091933  0.113250  0.098998  0.092309
# Bell      3.785636  3.868283  3.815402  3.759353  3.287451  2.735081
# Bexar     3.531182  3.486804  3.540411  3.524118  3.482455  3.460764
# Bowie     7.351737  6.449875  6.636281  6.277476  6.476405  6.300118
#
#               3q14      4q14      1q15      2q15  ...      3q17      4q17  \
# county                                            ...
# Angelina  3.903598  3.949308  3.908970  3.851704  ...  4.003234  4.028282
# Bastrop   0.073580  0.084282  0.098926  0.093650  ...  0.047432  0.068651
# Bell      2.534750  3.038192  2.975280  4.917622  ...  3.887514  4.000583
# Bexar     3.589123  3.596278  3.654202  3.573107  ...  3.611293  3.698055
# Bowie     6.694615  6.729012  6.863795  6.842376  ...  6.917786  6.644815
#
#               1q18      2q18      3q18      4q18      1q19      2q19  \
# county
# Angelina  4.154787  4.004243  4.089779  3.665519  4.223953  4.171425
# Bastrop   0.062961  0.046010  0.008475  0.047221  0.049654  0.060294
# Bell      3.889837  3.843808  3.747061  3.883680  3.748089  3.744923
# Bexar     3.703316  3.632400  3.586749  3.685366  3.561545  3.581422
# Bowie     6.440529  6.175073  6.398784  6.352757  6.438186  6.459586
#
#               3q19      4q19
# county
# Angelina  4.397524  4.285616
# Bastrop   0.043743  0.046107
# Bell      3.692818  3.652228
# Bexar     3.651632  3.656333
# Bowie     6.438186  6.362216
#
# [5 rows x 28 columns]

# %% [markdown]
# # Autoregression to Predict 2019 Social Factors
#
# ### Insert Details
#
# For the first part of our project, we decided to use an autoregressive model to predict social factors in 2019 using the previous years.  We then compared this to the actual social data from 2019.

# %% [markdown]
# # Nonlinear vs Linear Neural Net
#
# ### Using Social Factors to predict Health Outcomes
#
# For the next part of our project, we wanted to use our social factors to predict hospital discharges.  We first classified each county as "below average health", "average health", and "above average health" depending on the percentage of discharges they had relative to their population.
#
# We then ran both a nonlinear neural network with sigmoid activation functions, and a linear network to compare how they functioned relative to one another.
#
# Each model was run with social data from one year as inputs, and health outcome prediction (below, average, above) on the same respective year where below average health corresponds to an output of $100$, average to $110$ and above to $111$.

# %%
df_train_features = hd_df.groupby(np.arange(len(hd_df.columns))//4, axis=1).mean()
df_train_features.columns = ["2013", "2014", "2015", "2016", "2017", "2018", "2019"]
print(df_train_features.shape)
df_train_features.head()
# Out:
# (51, 7)
#               2013      2014      2015      2016      2017      2018      2019
# county
# Angelina  3.946298  3.848176  3.719706  3.689175  3.957975  3.978582  4.269630
# Bastrop   0.112251  0.087292  0.080790  0.054672  0.054297  0.041167  0.049950
# Bell      3.807168  2.898868  3.949127  3.852352  3.895622  3.841097  3.709514
# Bexar     3.520629  3.532155  3.626351  3.593684  3.574073  3.651958  3.612733
# Bowie     6.678842  6.550038  6.738760  6.456394  6.701773  6.341786  6.424544

# %%
#separate each year into its own df
df_train_features_2013 = df_train_features.iloc[:, 0]
df_train_features_2014 = df_train_features.iloc[:, 1]
df_train_features_2015 = df_train_features.iloc[:, 2]
df_train_features_2016 = df_train_features.iloc[:, 3]
df_train_features_2017 = df_train_features.iloc[:, 4]
df_train_features_2018 = df_train_features.iloc[:, 5]
df_train_features_2019 = df_train_features.iloc[:, 6]

# %%
#calculate .33 quantile for each year
above_2013 = df_train_features_2013.quantile(0.33)
above_2014 = df_train_features_2014.quantile(0.33)
above_2015 = df_train_features_2015.quantile(0.33)
above_2016 = df_train_features_2016.quantile(0.33)
above_2017 = df_train_features_2017.quantile(0.33)
above_2018 = df_train_features_2018.quantile(0.33)
above_2019 = df_train_features_2019.quantile(0.33)

# %%
#calculate .66 quantile for each year
average_2013 = df_train_features_2013.quantile(0.66)
average_2014 = df_train_features_2014.quantile(0.66)
average_2015 = df_train_features_2015.quantile(0.66)
average_2016 = df_train_features_2016.quantile(0.66)
average_2017 = df_train_features_2017.quantile(0.66)
average_2018 = df_train_features_2018.quantile(0.66)
average_2019 = df_train_features_2019.quantile(0.66)

# %%
#calculate 1 quantile for each year
below_2013 = df_train_features_2013.quantile(1)
below_2014 = df_train_features_2014.quantile(1)
below_2015 = df_train_features_2015.quantile(1)
below_2016 = df_train_features_2016.quantile(1)
below_2017 = df_train_features_2017.quantile(1)
below_2018 = df_train_features_2018.quantile(1)
below_2019 = df_train_features_2019.quantile(1)

# %%
#train_x, test_x, train_y, test_y = train_test_split(df_train_features,df_train_labels,test_size=0.3)
