# %%
import pandas as pd
import numpy as np
from numpy import nan as Nan

# %%
def convert_county_name(input_county):
    return input_county[:input_county.find(" County")]

def convert_id(input_id):
    return input_id[9:]

# %%
county_df = pd.read_csv("datasets/before/2013social.csv").fillna(0) # county info
county_df.columns = county_df.iloc[0] # Set the top row as headers
county_df = county_df[1:]
county_df = county_df[["id", "Geographic Area Name"]]

county_df = county_df.rename(columns={"Geographic Area Name":"name", "id":"FIPS"})
county_df["name"] = county_df["name"].apply(convert_county_name)
county_df["FIPS"] = county_df["FIPS"].apply(convert_id)

county_df = county_df[((county_df["name"] != "Orange") & (county_df["name"] != "San Patricio"))]

county_df.to_csv("datasets/after/county.csv")

# county_df = county_df.set_index("name");

county_df.head()
# Out:
# 0   FIPS      name
# 1  48005  Angelina
# 2  48021   Bastrop
# 3  48027      Bell
# 4  48029     Bexar
# 5  48037     Bowie

# %%
def find_county_name(input_num):
    if not (str)(input_num).isdigit():
        return Nan
    
    fips = str(48000 + int(str(input_num)))

    if (county_df["FIPS"] == fips).any():
        return county_df[county_df["FIPS"] == fips].iloc[0]["name"]
    else:
        return Nan

# %%
IP_df = []

for year in range(2013, 2020): # Get Hospital Discharges Data from 2013 and 2019
    reader = "datasets/before/" + str(year) + "IP.xlsx"
    IP_original = pd.read_excel(reader).fillna(0)
    IPyear_df = pd.DataFrame()
    for i in range (1, 5): # Get the data of four quarters
        quarter = str(i) + "q" + str(year % 100)
        # print(quarter)
        if year <= 2016:
            qid = quarter + " Inpatient Discharges"
        else:
            qid = "q" + str(i)
            
        if 2014 <= year and year <= 2016:
            county = "Hospital County"
        elif year >= 2017:
            county = "COUNTY"
        else:
            county = "Hospital county"
            
        IPyear_df[[quarter]] = IP_original.loc[:,[county, qid]].groupby(county).sum()
    
    IPyear_df.index.names = ["county"]
    
    if year >= 2017: # Find County name using FIPS
        IPyear_df = IPyear_df.reset_index()
        IPyear_df["name"] = IPyear_df["county"].apply(find_county_name)
        IPyear_df = IPyear_df.dropna().drop(columns=["county"]).set_index("name")
        IPyear_df.index.names = ["county"]
        
    IP_df.append(IPyear_df) #IP_df[i] saves data from Year (2013 + i)

# %%
mergedIP_df = IP_df[0] # 2010 data
for year in range(2014, 2020):
    mergedIP_df = pd.concat([mergedIP_df, IP_df[year - 2013]], axis=1, join='inner')

# %%
mergedIP_df
# Out:
#                  1q13      2q13      3q13      4q13      1q14      2q14  \
# county
# Angelina       3113.0    3440.0    3278.0    3949.0    3244.0    3354.0
# Bastrop          98.0      85.0      69.0      85.0      74.0      69.0
# Bell          11955.0   12216.0   12049.0   11872.0   10683.0    8888.0
# Bexar         61985.0   61206.0   62147.0   61861.0   62292.0   61904.0
# Bowie          6823.0    5986.0    6159.0    5826.0    6025.0    5861.0
# Brazoria       1993.0    1866.0    1864.0    1891.0    1913.0    1819.0
# Brazos         6915.0    6658.0    6673.0    6540.0    6532.0    6470.0
# Cameron       12777.0   11603.0   11434.0   13233.0    9903.0   12951.0
# Collin        22589.0   22388.0   22225.0   22337.0   22295.0   24704.0
# Comal          1885.0    1736.0    1715.0    1660.0    1701.0    1636.0
# Coryell           0.0     208.0     178.0     195.0     115.0     131.0
# 1      50     48       1  Texas  Anderson     2        58452        35518
# 2      50     48       1  Texas  Anderson     3        58493        35542
# 3      50     48       1  Texas  Anderson     4        58394        35586
# 4      50     48       1  Texas  Anderson     5        58059        35327
#
#    POPEST_FEM  UNDER5_TOT  ...  AGE7579_FEM  AGE8084_TOT  AGE8084_MALE  \
# 0       22937        3135  ...          757          898           349
# 1       22934        3135  ...          758          897           349
# 2       22951        3129  ...          758          903           358
# 3       22808        3105  ...          751          916           368
# 4       22732        2999  ...          780          942           389
#
#    AGE8084_FEM  AGE85PLUS_TOT  AGE85PLUS_MALE  AGE85PLUS_FEM  MEDIAN_AGE_TOT  \
# 0          549            865             298            567            39.1
# 1          548            865             298            567            39.1
# 2          545            864             301            563            39.1
# 3          548            842             294            548            39.1
# 4          553            851             302            549            39.2
#
#    MEDIAN_AGE_MALE  MEDIAN_AGE_FEM
# 0             38.8            39.9
# 1             38.8            39.9
# 2             38.8            39.9
# 3             38.7            40.2
# 4             38.7            40.5
#
# [5 rows x 96 columns]

# %%
# Get percentage
for county in mergedIP_df.index:
    for quarter in mergedIP_df.columns:
        year = int(quarter[3:])
        div = population_df.loc[(population_df["CTYNAME"] == county)].loc[:, "POPESTIMATE"].reset_index(drop=True)[year]
        mergedIP_df.at[county, quarter] =  float(mergedIP_df.at[county, quarter]) * (float)(100) / (float)(div)

# %%
mergedIP_df.to_csv("datasets/after/mergedIP.csv")
# mergedIP_df

# %%
def is_float(input_val):
    try:
        num = float(input_val)
    except ValueError:
        return False
    return True

# %%
SOC_df = []

for year in range(2013, 2020): # Get Social Factors from 2010 and 2019
    reader = "datasets/before/" + str(year) + "social.csv"
    SOC_original = pd.read_csv(reader).fillna(0)
    SOC_original.columns = SOC_original.iloc[0] # Set the top row as headers
    SOC_original = SOC_original[1:]

    SOC_original = SOC_original.rename(columns={"Geographic Area Name":"county", "id":"FIPS"})
    SOC_original["county"] = SOC_original["county"].apply(convert_county_name)
    SOC_original["FIPS"] = SOC_original["FIPS"].apply(convert_id)
    SOC_original = SOC_original.set_index("county");
    
    tmp = mergedIP_df[[]]
    for c in SOC_original.columns:
        
        if year == 2018:
            if c.lower()[:18] != "percent estimate!!":
                continue
            else:
                factor = c.lower()[18:]
        else:
            if c.lower()[:9] != "percent!!":
                continue
            else:
                factor = c.lower()[9:]
                
        if (SOC_original[c] == "N").any():
            continue
                
        val = SOC_original.loc["Harrison", c]
        
        if (isinstance(val, pd.Series)) or (not is_float(val)):
            continue
        
        num = float(val)
        if num > 100.0:
            continue
        
        tmp = pd.concat([tmp, SOC_original.loc[:,c]], axis=1, join='inner')
        tmp = tmp.rename(columns={c: factor})
        
    SOC_original = tmp
    SOC_df.append(SOC_original) #SOC_df[i] saves data from Year (2010 + i)

# %%
SOC_df[1] # in percentage
# Out:
#             households by type!!total households!!family households (families)  \
# county
# Angelina                                                  71.3
# Bastrop                                                   74.6
# Bell                                                      70.0
# Bexar                                                     66.7
# Bowie                                                     69.5
# Brazoria                                                  76.5
# Brazos                                                    52.7
# Cameron                                                   79.5
# Collin                                                    73.9
# Comal                                                     72.0
# Coryell                                                   71.6
# Dallas                                                    65.4
# Denton                                                    71.9
# Ector                                                     70.4
# El Paso                                                   74.3
# Ellis                                                     76.4
# Fort Bend                                                 80.4
# Galveston                                                 67.6
# Grayson                                                   70.5
# Gregg                                                     67.5
# Guadalupe                                                 78.4
# Harris                                                    67.0
# Harrison                                                  73.3
# Hays                                                      64.1
# Henderson                                                 73.4
# Hidalgo                                                   83.0
# Hunt                                                      68.9
# Jefferson                                                 63.7
# Johnson                                                   77.1
# Kaufman                                                   76.5
# Liberty                                                   69.4
# Lubbock                                                   63.4
# McLennan                                                  66.0
# Midland                                                   69.4
# Montgomery                                                73.8
# Nacogdoches                                               64.1
# Nueces                                                    68.7
# Parker                                                    72.3
# Potter                                                    64.3
# Randall                                                   70.7
# Rockwall                                                  83.3
# Smith                                                     68.7
# Tarrant                                                   68.7
# Taylor                                                    71.0
# Tom Green                                                 60.3
# Travis                                                    56.0
# Victoria                                                  70.1
# Walker                                                    56.4
# Webb                                                      82.1
# Wichita                                                   60.9
# Williamson                                                72.5
#
#             households by type!!total households!!family households (families)!!with own children under 18 years  \
# county
# Angelina                                                  34.3
# Bastrop                                                   27.4
# Bell                                                      35.3
# Bexar                                                     31.8
# Bowie                                                     28.3
# Brazoria                                                  39.1
# Brazos                                                    27.1
# Cameron                                                   40.9
# Collin                                                    40.4
# Comal                                                     26.7
# Coryell                                                   34.8
# Dallas                                                    32.6
# Denton                                                    37.9
# Ector                                                     31.8
# El Paso                                                   35.4
# Ellis                                                     33.1
# Fort Bend                                                 41.1
# Galveston                                                 31.0
# Grayson                                                   27.8
# Gregg                                                     28.8
# Guadalupe                                                 33.7
# Harris                                                    33.4
# Harrison                                                  29.8
# Hays                                                      29.9
# Henderson                                                 26.7
# Hidalgo                                                   43.6
# Hunt                                                      27.9
# Jefferson                                                 30.0
# Johnson                                                   35.0
# Kaufman                                                   36.8
# Liberty                                                   31.2
# Lubbock                                                   28.6
# McLennan                                                  28.0
# Midland                                                   33.3
# Montgomery                                                35.6
# Nacogdoches                                               26.7
# Nueces                                                    30.0
# Parker                                                    29.6
# Potter                                                    29.8
# Randall                                                   32.5
# Rockwall                                                  40.4
# Smith                                                     28.4
# Tarrant                                                   34.2
# Taylor                                                    28.5
# Tom Green                                                 23.2
# Travis                                                    27.4
# Victoria                                                  29.8
# Walker                                                    16.8
# Webb                                                      45.8
# Wichita                                                   26.2
# Williamson                                                37.9
#
#             households by type!!total households!!family households (families)!!married-couple family  \
# county
# Angelina                                                  47.3
# Bastrop                                                   56.5
# Bell                                                      50.3
# Bexar                                                     44.5
# Bowie                                                     46.9
# Brazoria                                                  59.9
# Brazos                                                    37.5
# Cameron                                                   49.7
# Collin                                                    60.7
# Comal                                                     60.3
# Coryell                                                   59.0
# Dallas                                                    42.6
# Denton                                                    56.1
# Ector                                                     50.3
# El Paso                                                   48.9
# Ellis                                                     61.3
# Fort Bend                                                 63.8
# Galveston                                                 50.9
# Grayson                                                   53.6
# Gregg                                                     46.1
# Guadalupe                                                 58.0
# Harris                                                    45.9
# Harrison                                                  57.6
# Hays                                                      47.6
# Henderson                                                 58.5
# Hidalgo                                                   55.0
# Hunt                                                      51.7
# Jefferson                                                 39.2
# Johnson                                                   59.1
# Kaufman                                                   56.3
# Liberty                                                   52.4
# Lubbock                                                   43.7
# McLennan                                                  48.0
# Midland                                                   51.0
# Montgomery                                                60.4
# Nacogdoches                                               46.2
# Nueces                                                    45.4
# Parker                                                    61.5
# Potter                                                    40.5
# Randall                                                   54.5
# Rockwall                                                  70.3
# Smith                                                     50.5
# Tarrant                                                   49.7
# Taylor                                                    51.6
# Tom Green                                                 46.1
# Travis                                                    41.2
# Victoria                                                  52.2
# Walker                                                    41.1
# Webb                                                      51.8
# Wichita                                                   43.5
# Williamson                                                57.6
#
#             households by type!!total households!!family households (families)!!married-couple family!!with own children under 18 years  \
# county
# Angelina                                                  19.3
# Bastrop                                                   17.8
# Bell                                                      22.6
# Bexar                                                     19.6
# Bowie                                                     15.1
# Brazoria                                                  29.9
# Brazos                                                    17.7
# Cameron                                                   23.6
# Collin                                                    32.6
# Comal                                                     20.5
# Coryell                                                   26.4
# Dallas                                                    19.9
# Denton                                                    29.0
# Ector                                                     22.0
# El Paso                                                   22.5
# Ellis                                                     24.5
# Fort Bend                                                 32.5
# Galveston                                                 23.2
# Grayson                                                   19.5
# Gregg                                                     17.6
# Guadalupe                                                 22.3
# Harris                                                    22.2
# Harrison                                                  21.5
# Hays                                                      22.0
# Henderson                                                 19.1
# Hidalgo                                                   28.0
# Hunt                                                      16.7
# Jefferson                                                 15.6
# Johnson                                                   24.5
# Kaufman                                                   26.2
# Liberty                                                   20.4
# Lubbock                                                   18.4
# McLennan                                                  19.4
# Midland                                                   22.9
# Montgomery                                                27.0
# Nacogdoches                                               16.6
# Nueces                                                    19.6
# Parker                                                    22.7
# Potter                                                    18.1
# Randall                                                   23.2
# Rockwall                                                  31.9
# Smith                                                     19.4
# Tarrant                                                   23.0
# Taylor                                                    17.5
# Tom Green                                                 17.0
# Travis                                                    18.7
# Victoria                                                  18.5
# Walker                                                    11.6
# Webb                                                      28.8
# Wichita                                                   15.7
# Williamson                                                27.8
#
#             households by type!!total households!!family households (families)!!male householder, no wife present, family  \
# county
# Angelina                                                   6.5
# Bastrop                                                    7.0
# Bell                                                       5.3
# Bexar                                                      5.5
# Bowie                                                      5.1
# Brazoria                                                   5.8
# Brazos                                                     3.3
# Cameron                                                    5.7
# Collin                                                     3.7
# Comal                                                      2.6
# Coryell                                                    3.6
# Dallas                                                     6.1
# Denton                                                     4.2
# Ector                                                      6.0
# El Paso                                                    6.0
# Ellis                                                      4.0
# Fort Bend                                                  3.7
# Galveston                                                  4.3
# Grayson                                                    3.4
# Gregg                                                      5.4
# Guadalupe                                                  5.7
# Harris                                                     5.8
# Harrison                                                   2.6
# Hays                                                       5.9
# Henderson                                                  4.8
# Hidalgo                                                    6.2
# Hunt                                                       3.5
# Jefferson                                                  4.5
# Johnson                                                    4.5
# Kaufman                                                    5.7
# Liberty                                                    5.8
# Lubbock                                                    6.3
# McLennan                                                   4.5
# Midland                                                    5.7
# Montgomery                                                 4.2
# Nacogdoches                                                7.1
# Nueces                                                     7.1
# Parker                                                     1.4
# Potter                                                     4.7
# Randall                                                    3.6
# Rockwall                                                   2.4
# Smith                                                      4.4
# Tarrant                                                    4.6
# Taylor                                                     5.7
# Tom Green                                                  3.6
# Travis                                                     4.2
# Victoria                                                   5.7
# Walker                                                     4.6
# Webb                                                       6.0
# Wichita                                                    4.9
# Williamson                                                 3.9
#
#             households by type!!total households!!family households (families)!!male householder, no wife present, family!!with own children under 18 years  \
# county
# Angelina                                                   4.3
# Bastrop                                                    4.8
# Bell                                                       2.9
# Bexar                                                      2.5
# Bowie                                                      2.9
# Brazoria                                                   3.0
# Brazos                                                     1.6
# Cameron                                                    3.1
# Collin                                                     1.9
# Comal                                                      1.4
# Coryell                                                    1.6
# Dallas                                                     2.8
# Denton                                                     1.9
# Ector                                                      2.6
# El Paso                                                    2.3
# Ellis                                                      2.6
# Fort Bend                                                  1.6
# Galveston                                                  1.9
# Grayson                                                    1.0
# Gregg                                                      1.6
# Guadalupe                                                  2.5
# Harris                                                     2.6
# Harrison                                                   1.6
# Hays                                                       3.2
# Henderson                                                  2.9
# Hidalgo                                                    2.4
# Hunt                                                       2.2
# Jefferson                                                  2.2
# Johnson                                                    3.4
# Kaufman                                                    3.0
# Liberty                                                    3.3
# Lubbock                                                    3.0
# McLennan                                                   1.3
# Midland                                                    2.4
# Montgomery                                                 2.6
# Nacogdoches                                                2.9
# Nueces                                                     2.5
# Parker                                                     0.7
# Potter                                                     1.5
# Randall                                                    2.2
# Rockwall                                                   1.2
# Smith                                                      1.3
# Tarrant                                                    2.3
# Taylor                                                     3.4
# Tom Green                                                  1.3
# Travis                                                     2.0
# Victoria                                                   3.4
# Walker                                                     1.4
# Webb                                                       2.8
# Wichita                                                    3.2
# Williamson                                                 2.7
#
#             households by type!!total households!!family households (families)!!female householder, no husband present, family  \
# county
# Angelina                                                  17.5
# Bastrop                                                   11.0
# Bell                                                      14.5
# Bexar                                                     16.7
# Bowie                                                     17.5
# Brazoria                                                  10.8
# Brazos                                                    11.9
# Cameron                                                   24.0
# Collin                                                     9.6
# Comal                                                      9.1
# Coryell                                                    9.0
# Dallas                                                    16.7
# Denton                                                    11.6
# Ector                                                     14.1
# El Paso                                                   19.3
# Ellis                                                     11.0
# Fort Bend                                                 13.0
# Galveston                                                 12.4
# Grayson                                                   13.4
# Gregg                                                     16.0
# Guadalupe                                                 14.7
# Harris                                                    15.3
# Harrison                                                  13.1
# Hays                                                      10.6
# Henderson                                                 10.1
# Hidalgo                                                   21.8
# Hunt                                                      13.6
# Jefferson                                                 20.1
# Johnson                                                   13.6
# Kaufman                                                   14.5
# Liberty                                                   11.2
# Lubbock                                                   13.4
# McLennan                                                  13.5
# Midland                                                   12.7
# Montgomery                                                 9.1
# Nacogdoches                                               10.8
# Nueces                                                    16.2
# Parker                                                     9.3
# Potter                                                    19.0
# Randall                                                   12.5
# Rockwall                                                  10.6
# Smith                                                     13.8
# Tarrant                                                   14.4
# Taylor                                                    13.7
# Tom Green                                                 10.5
# Travis                                                    10.7
# Victoria                                                  12.3
# Walker                                                    10.7
# Webb                                                      24.3
# Wichita                                                   12.5
# Williamson                                                11.1
#
#             households by type!!total households!!family households (families)!!female householder, no husband present, family!!with own children under 18 years  \
# county
# Angelina                                                  10.6
# Bastrop                                                    4.8
# Bell                                                       9.7
# Bexar                                                      9.7
# Bowie                                                     10.4
# Brazoria                                                   6.1
# Brazos                                                     7.7
# Cameron                                                   14.2
# Collin                                                     5.9
# Comal                                                      4.8
# Coryell                                                    6.8
# Dallas                                                     9.8
# Denton                                                     7.0
# Ector                                                      7.1
# ...
# Bell                                                       5.5
# Bexar                                                     12.5
# Bowie                                                      3.2
# Brazoria                                                   8.5
# Brazos                                                     9.1
# Cameron                                                   30.2
# Collin                                                     9.5
# Comal                                                      4.1
# Coryell                                                    4.7
# Dallas                                                    21.8
# Denton                                                     7.8
# Ector                                                     13.2
# El Paso                                                   31.1
# Ellis                                                     12.3
# Fort Bend                                                 12.7
# Galveston                                                  7.0
# Grayson                                                    4.5
# Gregg                                                      7.1
# Guadalupe                                                  6.8
# Harris                                                    20.9
# Harrison                                                   6.3
# Hays                                                       8.6
# Henderson                                                  5.5
# Hidalgo                                                   31.8
# Hunt                                                       4.2
# Jefferson                                                  8.1
# Johnson                                                    5.6
# Kaufman                                                    7.0
# Liberty                                                    7.0
# Lubbock                                                    5.2
# McLennan                                                   9.6
# Midland                                                   11.0
# Montgomery                                                 7.8
# Nacogdoches                                                7.7
# Nueces                                                     7.5
# Parker                                                     2.7
# Potter                                                    12.5
# Randall                                                    3.0
# Rockwall                                                   5.6
# Smith                                                      8.5
# Tarrant                                                   11.9
# Taylor                                                     3.4
# Tom Green                                                  6.6
# Travis                                                    12.6
# Victoria                                                   8.6
# Walker                                                     6.2
# Webb                                                      37.9
# Wichita                                                    6.8
# Williamson                                                 7.3
#
#             computers and internet use!!total households!!with a computer  \
# county
# Angelina                                                  85.1
# Bastrop                                                   88.2
# Bell                                                      89.8
# Bexar                                                     85.0
# Bowie                                                     73.2
# Brazoria                                                  89.5
# Brazos                                                    91.5
# Cameron                                                   64.7
# Collin                                                    95.9
# Comal                                                     89.3
# Coryell                                                   86.4
# Dallas                                                    84.4
# Denton                                                    95.4
# Ector                                                     87.8
# El Paso                                                   77.4
# Ellis                                                     87.9
# Fort Bend                                                 95.3
# Galveston                                                 87.4
# Grayson                                                   82.9
# Gregg                                                     82.4
# Guadalupe                                                 87.2
# Harris                                                    85.5
# Harrison                                                  72.7
# Hays                                                      90.1
# Henderson                                                 74.2
# Hidalgo                                                   77.5
# Hunt                                                      79.6
# Jefferson                                                 70.6
# Johnson                                                   89.5
# Kaufman                                                   86.1
# Liberty                                                   73.4
# Lubbock                                                   86.8
# McLennan                                                  81.7
# Midland                                                   88.5
# Montgomery                                                89.7
# Nacogdoches                                               81.9
# Nueces                                                    84.4
# Parker                                                    87.7
# Potter                                                    75.0
# Randall                                                   89.2
# Rockwall                                                  94.4
# Smith                                                     85.5
# Tarrant                                                   89.3
# Taylor                                                    88.9
# Tom Green                                                 78.8
# Travis                                                    91.3
# Victoria                                                  78.9
# Walker                                                    85.4
# Webb                                                      72.1
# Wichita                                                   82.3
# Williamson                                                92.3
#
#             computers and internet use!!total households!!with a broadband internet subscription
# county
# Angelina                                                  74.6
# Bastrop                                                   77.6
# Bell                                                      77.1
# Bexar                                                     72.6
# Bowie                                                     62.3
# Brazoria                                                  78.5
# Brazos                                                    76.8
# Cameron                                                   52.2
# Collin                                                    88.3
# Comal                                                     85.1
# Coryell                                                   80.0
# Dallas                                                    71.4
# Denton                                                    86.7
# Ector                                                     77.2
# El Paso                                                   64.5
# Ellis                                                     72.8
# Fort Bend                                                 88.7
# Galveston                                                 76.3
# Grayson                                                   69.8
# Gregg                                                     67.6
# Guadalupe                                                 75.9
# Harris                                                    74.5
# Harrison                                                  58.0
# Hays                                                      79.4
# Henderson                                                 61.7
# Hidalgo                                                   58.1
# Hunt                                                      65.4
# Jefferson                                                 61.6
# Johnson                                                   75.0
# Kaufman                                                   69.7
# Liberty                                                   65.2
# Lubbock                                                   69.5
# McLennan                                                  66.1
# Midland                                                   82.1
# Montgomery                                                80.0
# Nacogdoches                                               67.7
# Nueces                                                    73.3
# Parker                                                    78.1
# Potter                                                    61.7
# Randall                                                   81.3
# Rockwall                                                  89.0
# Smith                                                     76.2
# Tarrant                                                   77.6
# Taylor                                                    73.4
# Tom Green                                                 68.2
# Travis                                                    82.2
# Victoria                                                  65.4
# Walker                                                    64.2
# Webb                                                      56.2
# Wichita                                                   65.2
# Williamson                                                86.7
#
# [51 rows x 68 columns]

# %%
for year in range(2013, 2020):
    print(SOC_df[year - 2013].shape)
# Out:
# (51, 61)
# (51, 68)
# (51, 65)
# (51, 68)
# (51, 65)
# (51, 68)
# (51, 65)

# %%
factors_df = pd.DataFrame(SOC_df[0].columns).set_index([0])

for year in range(2014, 2020):
    factors_df = pd.concat([factors_df, pd.DataFrame(SOC_df[year - 2013].columns).set_index([0])], axis=1, join='inner')    
    
factors_df.shape
# Out:
# (48, 0)

# %%
factors_df = factors_df.reset_index().reset_index()
factors_df.columns = ["label", "name"]

factors_df.to_csv("datasets/after/factors.csv")

# %%
factors_df.head() # nLm means label n in Year 20m (e.g. 00L13 means 0th label in Year 2013)
# Out:
#    label                                               name
# 0      0  school enrollment!!population 3 years and over...
# 1      1  school enrollment!!population 3 years and over...
# 2      2  school enrollment!!population 3 years and over...
# 3      3  school enrollment!!population 3 years and over...
# 4      4  school enrollment!!population 3 years and over...

# %%
mergedSOC_df = pd.DataFrame()
mergedSOC_df = mergedIP_df[[]]

for year in range(2013, 2020):
    for i in range(0, factors_df.shape[0]):
        if (i < 10):
            label = "0" + str(i) + "L" + str(year % 100)
        else:
            label = str(i) + "L" + str(year % 100)
            
        factor_name = factors_df.at[i, "name"]
        mergedSOC_df = pd.concat([mergedSOC_df, SOC_df[year - 2013].loc[:,factor_name]], axis=1, join='inner')    
        
        #tmp = pd.concat([tmp, SOC_original.loc[:,c]], axis=1, join='inner')
        mergedSOC_df = mergedSOC_df.rename(columns={factor_name: label})

mergedSOC_df.to_csv("datasets/after/mergedSOC.csv")

# %%
mergedSOC_df
# Out:
#             00L13 01L13 02L13 03L13 04L13 05L13 06L13 07L13 08L13 09L13  ...  \
# county                                                                   ...
# Angelina      8.8   6.8  48.6  19.6  16.3   7.4  14.5  29.6  26.6   6.1  ...
# Bastrop       3.1   8.3  50.9  20.1  17.6  10.3  10.1  31.0  24.5   6.6  ...
# Bell          5.6   5.5  41.7  16.9  30.3   4.4   4.1  30.2  28.3  10.2  ...
